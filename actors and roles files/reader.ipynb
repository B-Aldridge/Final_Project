# %%
import pandas as pd

# %%
title_principals_df=pd.read_csv('title_principals.tsv', sep='\t')

# %%
names_basics_df=pd.read_csv('name_basics.tsv', sep='\t')

# %%
title_basics_df=pd.read_csv("title_basics.tsv", sep='\t')
# Out:
# c:\Users\Skynet\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3186: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df=title_principals_df.merge(names_basics_df)

# %%
df=df.merge(title_basics_df)

# %%
df.head(5)
# Out:
#       tconst  ordering     nconst         category                      job  \
# 0  tt0000001         1  nm1588970             self                       \N
# 1  tt0000001         2  nm0005690         director                       \N
# 2  tt0000001         3  nm0374658  cinematographer  director of photography
# 3  tt7513040         2  nm1588970  archive_footage                       \N
# 4  tt7513040         7  nm0249379  archive_footage                       \N
#
#   characters           primaryName birthYear deathYear  \
# 0   ["Self"]            Carmencita      1868      1910
# 1         \N  William K.L. Dickson      1860      1935
# 2         \N         William Heise      1847      1910
# 3   ["Self"]            Carmencita      1868      1910
# 4   ["Self"]      Thomas A. Edison      1847      1931
#
#                    primaryProfession                           knownForTitles  \
# 0                         soundtrack                      tt0057728,tt0000001
# 1  cinematographer,director,producer  tt1496763,tt1428455,tt0219560,tt0308254
# 2  cinematographer,director,producer  tt0241393,tt0229665,tt0285863,tt0241715
# 3                         soundtrack                      tt0057728,tt0000001
# 4    producer,director,miscellaneous  tt0004457,tt0001223,tt0361066,tt0242312
#
#   titleType          primaryTitle         originalTitle isAdult startYear  \
# 0     short            Carmencita            Carmencita       0      1894
# 1     short            Carmencita            Carmencita       0      1894
# 2     short            Carmencita            Carmencita       0      1894
# 3     short  Den gamla goda tiden  Den gamla goda tiden       0      1946
# 4     short  Den gamla goda tiden  Den gamla goda tiden       0      1946
#
#   endYear runtimeMinutes             genres
# 0      \N              1  Documentary,Short
# 1      \N              1  Documentary,Short
# 2      \N              1  Documentary,Short
# 3      \N              6  Documentary,Short
# 4      \N              6  Documentary,Short

# %%
df=df[["category","characters","primaryName","titleType","primaryTitle","originalTitle","startYear","genres"]]

# %%
df.head(5)
# Out:
#           category characters           primaryName titleType  \
# 0             self   ["Self"]            Carmencita     short
# 1         director         \N  William K.L. Dickson     short
# 2  cinematographer         \N         William Heise     short
# 3  archive_footage   ["Self"]            Carmencita     short
# 4  archive_footage   ["Self"]      Thomas A. Edison     short
#
#            primaryTitle         originalTitle startYear             genres
# 0            Carmencita            Carmencita      1894  Documentary,Short
# 1            Carmencita            Carmencita      1894  Documentary,Short
# 2            Carmencita            Carmencita      1894  Documentary,Short
# 3  Den gamla goda tiden  Den gamla goda tiden      1946  Documentary,Short
# 4  Den gamla goda tiden  Den gamla goda tiden      1946  Documentary,Short

# %%
df['category'].value_counts()
# Out:
# actor                  12716628
# self                    9902086
# actress                 9883943
# writer                  8101130
# director                6652693
# producer                3755695
# cinematographer         1976672
# composer                1933372
# editor                  1926201
# archive_footage          377477
# production_designer      372252
# archive_sound              4179
# Name: category, dtype: int64

# %%
cleaned_df=df[df['category'].isin(['actor','actress'])]

# %%
cleaned_df['category'].value_counts()
# Out:
# actor      12716628
# actress     9883943
# Name: category, dtype: int64

# %%
cleaned_df
# Out:
#          category        characters       primaryName titleType  \
# 14          actor    ["Blacksmith"]    Charles Kayser     short
# 15          actor     ["Assistant"]          John Ott     short
# 21          actor                \N  James J. Corbett     short
# 22          actor                \N    Peter Courtney     short
# 25          actor  ["Sneezing Man"]          Fred Ott     short
# ...           ...               ...               ...       ...
# 57602307    actor          ["Lisa"]    Dovin Milligan   tvMovie
# 57602320    actor     ["Narration"]   Brett Rosenberg     short
# 57602321    actor      ["Sprecher"]      David Nathan     movie
# 57602322    actor                \N  Helmut Schiffner     movie
# 57602323    actor                \N    Andree Steinke     movie
#
#                                                primaryTitle  \
# 14                                         Blacksmith Scene
# 15                                         Blacksmith Scene
# 21              Corbett and Courtney Before the Kinetograph
# 22              Corbett and Courtney Before the Kinetograph
# 25                   Edison Kinetoscopic Record of a Sneeze
# ...                                                     ...
# 57602307                                 Domestic Relations
# 57602320  A Shoelace, a Cup of Coffee, and The Turn of A...
# 57602321  Illenau - die Geschichte einer ehemaligen Heil...
# 57602322  Illenau - die Geschichte einer ehemaligen Heil...
# 57602323  Illenau - die Geschichte einer ehemaligen Heil...
#
#                                               originalTitle startYear  \
# 14                                         Blacksmith Scene      1893
# 15                                         Blacksmith Scene      1893
# 21              Corbett and Courtney Before the Kinetograph      1894
# 22              Corbett and Courtney Before the Kinetograph      1894
# 25                   Edison Kinetoscopic Record of a Sneeze      1894
# ...                                                     ...       ...
# 57602307                                 Domestic Relations      2018
# 57602320  A Shoelace, a Cup of Coffee, and The Turn of A...        \N
# 57602321  Illenau - die Geschichte einer ehemaligen Heil...      2017
# 57602322  Illenau - die Geschichte einer ehemaligen Heil...      2017
# 57602323  Illenau - die Geschichte einer ehemaligen Heil...      2017
#
#                          genres
# 14                 Comedy,Short
# 15                 Comedy,Short
# 21                  Short,Sport
# 22                  Short,Sport
# 25            Documentary,Short
# ...                         ...
# 57602307           Comedy,Drama
# 57602320  Animation,Drama,Short
# 57602321            Documentary
# 57602322            Documentary
# 57602323            Documentary
#
# [22600571 rows x 8 columns]

# %%
cleaned_df["titleType"].unique()
# Out:
# array(['short', 'movie', 'tvEpisode', 'video', 'tvSeries', 'tvMovie',
#        'tvMiniSeries', 'tvSpecial', 'tvShort', 'videoGame'], dtype=object)

# %%
cleaned_df=cleaned_df[cleaned_df['titleType'].isin(['movie'])]

# %%
cleaned_df=cleaned_df.loc[cleaned_df['startYear']!='\\N']
cleaned_df["startYear"]=cleaned_df["startYear"].astype(int)

# %%
cleaned_df=cleaned_df.loc[cleaned_df['startYear']>1912]

# %%
cleaned_df[cleaned_df['primaryTitle'].str.contains("The Terminator")==True]
# Out:
#          category          characters            primaryName titleType  \
# 11726304    actor  ["The Terminator"]  Arnold Schwarzenegger     movie
# 11726305    actor         ["Traxler"]          Paul Winfield     movie
# 11726308    actor      ["Kyle Reese"]          Michael Biehn     movie
# 11726310  actress    ["Sarah Connor"]         Linda Hamilton     movie
#
#             primaryTitle   originalTitle  startYear         genres
# 11726304  The Terminator  The Terminator       1984  Action,Sci-Fi
# 11726305  The Terminator  The Terminator       1984  Action,Sci-Fi
# 11726308  The Terminator  The Terminator       1984  Action,Sci-Fi
# 11726310  The Terminator  The Terminator       1984  Action,Sci-Fi

# %%
# Out:
# <bound method DataFrame.reindex of          category                      characters            primaryName  \
# 1573        actor                        Père Ubu         Michel Poujade
# 1574      actress                        Mère Ubu         Janine Grillon
# 1650      actress             Ojo, a Munchkin Boy       Violet MacMillan
# 1651        actor      Unc Nunkie, Ojo's Guardian            Frank Moore
# 1654        actor  Dr. Pipt, the Crooked Magician        Raymond Russell
# ...           ...                             ...                    ...
# 57602243    actor                 ["El Krokodil"]      Holger Düsterhöft
# 57602244    actor              ["Dr. van Edkill"]  Tristan Heinen-Bizjak
# 57602321    actor                    ["Sprecher"]           David Nathan
# 57602322    actor                              \N       Helmut Schiffner
# 57602323    actor                              \N         Andree Steinke
#
#          titleType                                       primaryTitle  \
# 1573         movie                               Ubu and the Big Thug
# 1574         movie                               Ubu and the Big Thug
# 1650         movie                           The Patchwork Girl of Oz
# 1651         movie                           The Patchwork Girl of Oz
# 1654         movie                           The Patchwork Girl of Oz
# ...            ...                                                ...
# 57602243     movie                      BADMEN (with a good behavior)
# 57602244     movie                      BADMEN (with a good behavior)
# 57602321     movie  Illenau - die Geschichte einer ehemaligen Heil...
# 57602322     movie  Illenau - die Geschichte einer ehemaligen Heil...
# 57602323     movie  Illenau - die Geschichte einer ehemaligen Heil...
#
#                                               originalTitle  startYear  \
# 1573                             Ubu et la grande Gidouille       1979
# 1574                             Ubu et la grande Gidouille       1979
# 1650                               The Patchwork Girl of Oz       1914
# 1651                               The Patchwork Girl of Oz       1914
# 1654                               The Patchwork Girl of Oz       1914
# ...                                                     ...        ...
# 57602243                      BADMEN (with a good behavior)       2018
# 57602244                      BADMEN (with a good behavior)       2018
# 57602321  Illenau - die Geschichte einer ehemaligen Heil...       2017
# 57602322  Illenau - die Geschichte einer ehemaligen Heil...       2017
# 57602323  Illenau - die Geschichte einer ehemaligen Heil...       2017
#
#                            genres
# 1573        Animation,Crime,Drama
# 1574        Animation,Crime,Drama
# 1650      Adventure,Comedy,Family
# 1651      Adventure,Comedy,Family
# 1654      Adventure,Comedy,Family
# ...                           ...
# 57602243            Comedy,Horror
# 57602244            Comedy,Horror
# 57602321              Documentary
# 57602322              Documentary
# 57602323              Documentary
#
# [1918598 rows x 8 columns]>

# %%
string="I love jam!"
print(string[2:-2])
chars=cleaned_df['characters'].iloc[11726304:11726310]
chars
#for i in range(0,len(chars)):
#   chars.iloc[i]=chars.iloc[i][2:-2]
# Out:
# love ja
# Series([], Name: characters, dtype: object)

# %%
cleaned_df.to_csv("actors.csv")

# %%
df[df['primaryName'].str.contains("Brad Pitt")==True]
# Out:
#               tconst  ordering      nconst         category       job  \
# 9103485    tt0097136         3   nm0000093            actor        \N
# 9103486    tt0098804         2   nm0000093            actor        \N
# 9103487    tt0100797         3   nm0000093            actor        \N
# 9103488    tt0101268         2   nm0000093            actor        \N
# 9103489    tt0104007         2   nm0000093            actor        \N
# ...              ...       ...         ...              ...       ...
# 9103881    tt9863946         7   nm0000093  archive_footage        \N
# 9103882    tt9893218         3   nm0000093         producer  producer
# 9103883    tt9898330         2   nm0000093             self        \N
# 41005596  tt10948248         8  nm10981109         composer        \N
# 41005597  tt10948282         8  nm10981109         composer        \N
#
#                            characters primaryName birthYear deathYear  \
# 9103485            ["Dwight Ingalls"]   Brad Pitt      1963        \N
# 9103486            ["Walker Lovejoy"]   Brad Pitt      1963        \N
# 9103487              ["Billy Canton"]   Brad Pitt      1963        \N
# 9103488               ["Joe Maloney"]   Brad Pitt      1963        \N
# 9103489                       ["Cox"]   Brad Pitt      1963        \N
# ...                               ...         ...       ...       ...
# 9103881   ["Floyd (Dick's Roommate)"]   Brad Pitt      1963        \N
# 9103882                            \N   Brad Pitt      1963        \N
# 9103883                      ["Self"]   Brad Pitt      1963        \N
# 41005596                           \N  Brad Pitts        \N        \N
# 41005597                           \N  Brad Pitts        \N        \N
#
#                    primaryProfession                           knownForTitles
# 9103485    producer,actor,soundtrack  tt0114746,tt0421715,tt1210166,tt0356910
# 9103486    producer,actor,soundtrack  tt0114746,tt0421715,tt1210166,tt0356910
# 9103487    producer,actor,soundtrack  tt0114746,tt0421715,tt1210166,tt0356910
# 9103488    producer,actor,soundtrack  tt0114746,tt0421715,tt1210166,tt0356910
# 9103489    producer,actor,soundtrack  tt0114746,tt0421715,tt1210166,tt0356910
# ...                              ...                                      ...
# 9103881    producer,actor,soundtrack  tt0114746,tt0421715,tt1210166,tt0356910
# 9103882    producer,actor,soundtrack  tt0114746,tt0421715,tt1210166,tt0356910
# 9103883    producer,actor,soundtrack  tt0114746,tt0421715,tt1210166,tt0356910
# 41005596  camera_department,composer                               tt10947226
# 41005597  camera_department,composer                               tt10947226
#
# [401 rows x 11 columns]
